# %% [markdown]
# # YouTube Content Strategy MDP
#
# This notebook reproduces the data processing, Markov transition estimation, value iteration, policy iteration, and constrained MDP LP results.

# %%
import pandas as pd
from src.youtube_mdp_model import run_pipeline
results = run_pipeline()
results.keys()

# %%
results['value_iteration_policy']

# %%
results['policy_iteration_policy']

# %%
results['cmdp_policy']

# %% [markdown]
# See `REPORT.md` for interpretation and limitations.
